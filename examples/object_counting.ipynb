# %% [markdown]
# <div align="center">
#
#   <a href="https://ultralytics.com/yolo" target="_blank">
#     <img width="1024", src="https://raw.githubusercontent.com/ultralytics/assets/main/yolov8/banner-yolov8.png"></a>
#
#   [中文](https://docs.ultralytics.com/zh/) | [한국어](https://docs.ultralytics.com/ko/) | [日本語](https://docs.ultralytics.com/ja/) | [Русский](https://docs.ultralytics.com/ru/) | [Deutsch](https://docs.ultralytics.com/de/) | [Français](https://docs.ultralytics.com/fr/) | [Español](https://docs.ultralytics.com/es/) | [Português](https://docs.ultralytics.com/pt/) | [Türkçe](https://docs.ultralytics.com/tr/) | [Tiếng Việt](https://docs.ultralytics.com/vi/) | [العربية](https://docs.ultralytics.com/ar/)
#
#   <a href="https://github.com/ultralytics/ultralytics/actions/workflows/ci.yaml"><img src="https://github.com/ultralytics/ultralytics/actions/workflows/ci.yaml/badge.svg" alt="Ultralytics CI"></a>
#   <a href="https://console.paperspace.com/github/ultralytics/ultralytics"><img src="https://assets.paperspace.io/img/gradient-badge.svg" alt="Run on Gradient"/></a>
#   <a href="https://colab.research.google.com/github/ultralytics/ultralytics/blob/main/examples/object_counting.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"></a>
#   <a href="https://www.kaggle.com/models/ultralytics/yolo11"><img src="https://kaggle.com/static/images/open-in-kaggle.svg" alt="Open In Kaggle"></a>
#   <a href="https://ultralytics.com/discord"><img alt="Discord" src="https://img.shields.io/discord/1089800235347353640?logo=discord&logoColor=white&label=Discord&color=blue"></a>
#
# Welcome to the Ultralytics YOLO11 🚀 notebook! <a href="https://github.com/ultralytics/ultralytics">YOLO11</a> is the latest version of the YOLO (You Only Look Once) AI models developed by <a href="https://ultralytics.com">Ultralytics</a>. This notebook serves as the starting point for exploring the various resources available to help you get started with YOLO11 and understand its features and capabilities.
#
# YOLO11 models are fast, accurate, and easy to use, making them ideal for various object detection and image segmentation tasks. They can be trained on large datasets and run on diverse hardware platforms, from CPUs to GPUs.
#
# We hope that the resources in this notebook will help you get the most out of YOLO11. Please browse the YOLO11 <a href="https://docs.ultralytics.com/guides/object-counting/"> Object Counting Docs</a> for details, raise an issue on <a href="https://github.com/ultralytics/ultralytics">GitHub</a> for support, and join our <a href="https://ultralytics.com/discord">Discord</a> community for questions and discussions!
#
# </div>

# %% [markdown]
# # Setup
#
# Pip install `ultralytics` and [dependencies](https://github.com/ultralytics/ultralytics/blob/main/pyproject.toml) and check software and hardware.
#
# [![PyPI - Version](https://img.shields.io/pypi/v/ultralytics?logo=pypi&logoColor=white)](https://pypi.org/project/ultralytics/) [![Downloads](https://static.pepy.tech/badge/ultralytics)](https://www.pepy.tech/projects/ultralytics) [![PyPI - Python Version](https://img.shields.io/pypi/pyversions/ultralytics?logo=python&logoColor=gold)](https://pypi.org/project/ultralytics/)

# %%
# %pip install ultralytics
import ultralytics

ultralytics.checks()
# Out:
# Ultralytics 8.2.18 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 29.8/78.2 GB disk)

# %% [markdown]
# # Object Counting using Ultralytics YOLO11 🚀
#
# ## What is Object Counting?
#
# Object counting with [Ultralytics YOLO11](https://github.com/ultralytics/ultralytics/) involves accurate identification and counting of specific objects in videos and camera streams. YOLO11 excels in real-time applications, providing efficient and precise object counting for various scenarios like crowd analysis and surveillance, thanks to its state-of-the-art algorithms and deep learning capabilities.
#
# ## Advantages of Object Counting?
#
# - **Resource Optimization:** Object counting facilitates efficient resource management by providing accurate counts, and optimizing resource allocation in applications like inventory management.
# - **Enhanced Security:** Object counting enhances security and surveillance by accurately tracking and counting entities, aiding in proactive threat detection.
# - **Informed Decision-Making:** Object counting offers valuable insights for decision-making, optimizing processes in retail, traffic management, and various other domains.
#
# ## Real World Applications
#
# |                                                                           Logistics                                                                           |                                                                     Aquaculture                                                                     |
# |:-------------------------------------------------------------------------------------------------------------------------------------------------------------:|:---------------------------------------------------------------------------------------------------------------------------------------------------:|
# | ![Conveyor Belt Packets Counting Using Ultralytics YOLO11](https://github.com/RizwanMunawar/ultralytics/assets/62513924/70e2d106-510c-4c6c-a57a-d34a765aa757) | ![Fish Counting in Sea using Ultralytics YOLO11](https://github.com/RizwanMunawar/ultralytics/assets/62513924/c60d047b-3837-435f-8d29-bb9fc95d2191) |
# |                                                    Conveyor Belt Packets Counting Using Ultralytics YOLO11                                                    |                                                    Fish Counting in Sea using Ultralytics YOLO11                                                    |

# %%
import cv2

from ultralytics import solutions

# Open the video file
cap = cv2.VideoCapture("/mnt/data/demo_video/surg_sponge.avi")
assert cap.isOpened(), "Error reading video file"

# Get video properties: width, height, and frames per second (fps)
w, h, fps = (int(cap.get(x)) for x in (cv2.CAP_PROP_FRAME_WIDTH, cv2.CAP_PROP_FRAME_HEIGHT, cv2.CAP_PROP_FPS))

# Define points for a line or region of interest in the video frame
line_points = [(20, 400), (1080, 400)]  # Line coordinates

# Initialize the video writer to save the output video
video_writer = cv2.VideoWriter("object_counting_output.avi", cv2.VideoWriter_fourcc(*"mp4v"), fps, (w, h))

# Initialize the Object Counter with visualization options and other parameters
counter = solutions.ObjectCounter(
    show=True,  # Display the image during processing
    region=line_points,  # Region of interest points
    model="/mnt/data/weights/all_data_v11/yolov11_all_data_02122024_5/weights/best.pt",  # Ultralytics YOLO11 model file
    line_width=2,  # Thickness of the lines and bounding boxes
)

# Process video frames in a loop
while cap.isOpened():
    success, im0 = cap.read()
    if not success:
        print("Video frame is empty or video processing has been successfully completed.")
        break

    # Use the Object Counter to count objects in the frame and get the annotated image
    im0 = counter.count(im0)

    # Write the annotated frame to the output video
    video_writer.write(im0)

# Release the video capture and writer objects
cap.release()
video_writer.release()

# Close all OpenCV windows
cv2.destroyAllWindows()
# Out:
# Ultralytics Solutions: ✅ {'region': [(20, 400), (1080, 400)], 'show_in': True, 'show_out': True, 'colormap': None, 'up_angle': 145.0, 'down_angle': 90, 'kpts': [6, 8, 10], 'analytics_type': 'line', 'json_file': None, 'records': 5, 'show': True, 'model': '/mnt/data/weights/all_data_v11/yolov11_all_data_02122024_5/weights/best.pt', 'line_width': 2}
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
# The DISPLAY environment variable isn't set.
#
# 0: 2048x2048 1 clamp, 1 gauze, 3 gloves, 1 incision, 1 forceps, 1 needle, 91.2ms
# Speed: 43.2ms preprocess, 91.2ms inference, 147.7ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 gauze, 3 gloves, 1 incision, 1 forceps, 1 needle, 87.8ms
# Speed: 20.9ms preprocess, 87.8ms inference, 1.3ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 4 gloves, 1 incision, 1 forceps, 1 needle, 87.5ms
# Speed: 19.0ms preprocess, 87.5ms inference, 1.6ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 4 gloves, 1 incision, 1 forceps, 1 needle, 87.5ms
# Speed: 17.1ms preprocess, 87.5ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 4 gloves, 1 incision, 2 forcepss, 1 needle, 87.1ms
# Speed: 14.7ms preprocess, 87.1ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 4 gloves, 1 incision, 2 forcepss, 1 needle, 86.8ms
# Speed: 15.1ms preprocess, 86.8ms inference, 1.6ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 sponge, 1 gauze, 4 gloves, 1 incision, 2 forcepss, 1 needle, 87.5ms
# Speed: 14.8ms preprocess, 87.5ms inference, 1.4ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 2 forcepss, 1 needle, 86.8ms
# Speed: 14.8ms preprocess, 86.8ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 2 forcepss, 1 needle, 87.2ms
# Speed: 14.7ms preprocess, 87.2ms inference, 1.6ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 gauze, 4 gloves, 1 incision, 2 forcepss, 1 needle, 86.8ms
# Speed: 14.9ms preprocess, 86.8ms inference, 1.4ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 3 gloves, 1 incision, 2 forcepss, 1 needle, 86.8ms
# Speed: 14.5ms preprocess, 86.8ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 3 gloves, 1 incision, 2 forcepss, 1 needle, 87.1ms
# Speed: 14.7ms preprocess, 87.1ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 3 gloves, 1 incision, 2 forcepss, 1 needle, 87.1ms
# Speed: 14.2ms preprocess, 87.1ms inference, 1.6ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 3 gloves, 1 incision, 2 forcepss, 1 needle, 87.2ms
# Speed: 14.8ms preprocess, 87.2ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 3 gloves, 1 incision, 2 forcepss, 1 needle, 87.2ms
# Speed: 14.8ms preprocess, 87.2ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 3 gloves, 1 incision, 2 forcepss, 1 needle, 87.3ms
# Speed: 15.0ms preprocess, 87.3ms inference, 1.6ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 3 gloves, 1 incision, 2 forcepss, 1 needle, 87.2ms
# Speed: 14.6ms preprocess, 87.2ms inference, 1.6ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 3 gloves, 1 incision, 2 forcepss, 1 needle, 86.8ms
# Speed: 14.8ms preprocess, 86.8ms inference, 1.6ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 3 gloves, 1 incision, 2 forcepss, 1 needle, 86.9ms
# Speed: 14.1ms preprocess, 86.9ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 3 gloves, 1 incision, 2 forcepss, 1 needle, 86.8ms
# Speed: 15.1ms preprocess, 86.8ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 3 gloves, 1 incision, 2 forcepss, 1 needle, 87.2ms
# Speed: 14.2ms preprocess, 87.2ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 3 gloves, 1 incision, 2 forcepss, 1 needle, 87.2ms
# Speed: 15.0ms preprocess, 87.2ms inference, 1.4ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 3 gloves, 1 incision, 2 forcepss, 1 needle, 86.8ms
# Speed: 14.5ms preprocess, 86.8ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 3 gloves, 1 incision, 2 forcepss, 1 needle, 86.8ms
# Speed: 14.7ms preprocess, 86.8ms inference, 1.6ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 3 gloves, 1 incision, 2 forcepss, 1 needle, 86.5ms
# Speed: 15.1ms preprocess, 86.5ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 3 gloves, 1 incision, 2 forcepss, 1 needle, 86.8ms
# Speed: 14.6ms preprocess, 86.8ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 3 gloves, 1 incision, 2 forcepss, 1 needle, 87.0ms
# Speed: 14.6ms preprocess, 87.0ms inference, 1.4ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 3 gloves, 1 incision, 2 forcepss, 1 needle, 86.8ms
# Speed: 14.9ms preprocess, 86.8ms inference, 1.6ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 3 gloves, 1 incision, 1 forceps, 1 needle, 87.4ms
# Speed: 14.5ms preprocess, 87.4ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 2 clamps, 1 sponge, 1 gauze, 3 gloves, 1 incision, 1 forceps, 1 needle, 87.2ms
# Speed: 14.7ms preprocess, 87.2ms inference, 1.6ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 2 clamps, 1 sponge, 1 gauze, 3 gloves, 1 incision, 1 forceps, 1 needle, 87.3ms
# Speed: 14.4ms preprocess, 87.3ms inference, 1.4ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 2 clamps, 1 sponge, 1 gauze, 3 gloves, 1 incision, 1 needle, 87.2ms
# Speed: 14.8ms preprocess, 87.2ms inference, 1.4ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 2 clamps, 1 sponge, 1 gauze, 3 gloves, 1 incision, 1 forceps, 1 needle, 87.2ms
# Speed: 14.9ms preprocess, 87.2ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 2 clamps, 1 sponge, 1 gauze, 3 gloves, 1 incision, 1 forceps, 1 needle, 87.5ms
# Speed: 14.7ms preprocess, 87.5ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 2 clamps, 1 sponge, 1 gauze, 3 gloves, 1 incision, 1 forceps, 1 needle, 87.2ms
# Speed: 14.7ms preprocess, 87.2ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 3 gloves, 1 incision, 2 forcepss, 1 needle, 87.3ms
# Speed: 14.9ms preprocess, 87.3ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 3 gloves, 1 incision, 1 forceps, 1 needle, 87.2ms
# Speed: 14.8ms preprocess, 87.2ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 3 gloves, 1 incision, 1 forceps, 1 needle, 86.9ms
# Speed: 14.8ms preprocess, 86.9ms inference, 1.4ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 3 gloves, 1 incision, 1 forceps, 86.8ms
# Speed: 14.7ms preprocess, 86.8ms inference, 1.3ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 3 gloves, 1 incision, 3 forcepss, 1 needle, 87.2ms
# Speed: 14.8ms preprocess, 87.2ms inference, 1.6ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 3 gloves, 1 incision, 2 forcepss, 87.2ms
# Speed: 14.7ms preprocess, 87.2ms inference, 1.4ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 3 gloves, 1 incision, 2 forcepss, 87.0ms
# Speed: 17.1ms preprocess, 87.0ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 3 gloves, 1 incision, 2 forcepss, 86.8ms
# Speed: 14.4ms preprocess, 86.8ms inference, 1.6ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 gauze, 3 gloves, 1 incision, 2 forcepss, 86.8ms
# Speed: 14.9ms preprocess, 86.8ms inference, 1.2ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 gauze, 3 gloves, 1 incision, 2 forcepss, 87.2ms
# Speed: 14.7ms preprocess, 87.2ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 gauze, 3 gloves, 1 incision, 2 forcepss, 87.2ms
# Speed: 14.8ms preprocess, 87.2ms inference, 1.2ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 3 gloves, 1 incision, 2 forcepss, 87.1ms
# Speed: 14.6ms preprocess, 87.1ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 3 gloves, 1 incision, 2 forcepss, 87.2ms
# Speed: 14.6ms preprocess, 87.2ms inference, 1.6ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 gauze, 3 gloves, 1 incision, 2 forcepss, 87.2ms
# Speed: 14.6ms preprocess, 87.2ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 gauze, 3 gloves, 1 incision, 2 forcepss, 87.2ms
# Speed: 14.9ms preprocess, 87.2ms inference, 1.3ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 gauze, 3 gloves, 1 incision, 2 forcepss, 87.0ms
# Speed: 14.6ms preprocess, 87.0ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 gauze, 3 gloves, 1 incision, 2 forcepss, 87.0ms
# Speed: 14.8ms preprocess, 87.0ms inference, 1.4ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 gauze, 3 gloves, 1 incision, 2 forcepss, 87.0ms
# Speed: 26.2ms preprocess, 87.0ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 gauze, 3 gloves, 1 incision, 3 forcepss, 87.3ms
# Speed: 14.7ms preprocess, 87.3ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 87.2ms
# Speed: 14.4ms preprocess, 87.2ms inference, 1.4ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 86.7ms
# Speed: 14.9ms preprocess, 86.7ms inference, 1.6ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 87.2ms
# Speed: 14.0ms preprocess, 87.2ms inference, 1.6ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 87.3ms
# Speed: 14.5ms preprocess, 87.3ms inference, 1.3ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 1 needle, 86.8ms
# Speed: 14.3ms preprocess, 86.8ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 1 needle, 87.1ms
# Speed: 14.7ms preprocess, 87.1ms inference, 1.4ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 3 sponges, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 1 needle, 86.8ms
# Speed: 15.3ms preprocess, 86.8ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 1 needle, 87.2ms
# Speed: 14.6ms preprocess, 87.2ms inference, 1.4ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 3 gloves, 1 incision, 2 forcepss, 1 needle, 86.9ms
# Speed: 14.7ms preprocess, 86.9ms inference, 1.4ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 3 gloves, 1 incision, 2 forcepss, 1 needle, 87.2ms
# Speed: 14.6ms preprocess, 87.2ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 3 gloves, 1 incision, 2 forcepss, 1 needle, 87.3ms
# Speed: 14.6ms preprocess, 87.3ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 3 gloves, 1 incision, 2 forcepss, 1 needle, 86.9ms
# Speed: 14.7ms preprocess, 86.9ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 3 gloves, 1 incision, 2 forcepss, 1 needle, 87.3ms
# Speed: 14.5ms preprocess, 87.3ms inference, 1.6ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 3 gloves, 1 incision, 2 forcepss, 1 needle, 87.2ms
# Speed: 14.6ms preprocess, 87.2ms inference, 1.3ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 3 gloves, 1 incision, 2 forcepss, 2 needles, 87.0ms
# Speed: 14.6ms preprocess, 87.0ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 3 gloves, 1 incision, 2 forcepss, 2 needles, 87.3ms
# Speed: 14.9ms preprocess, 87.3ms inference, 1.6ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 3 gloves, 1 incision, 2 forcepss, 2 needles, 87.2ms
# Speed: 14.5ms preprocess, 87.2ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 3 gloves, 1 incision, 2 forcepss, 86.9ms
# Speed: 15.1ms preprocess, 86.9ms inference, 1.6ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 3 gloves, 1 incision, 2 forcepss, 1 needle, 87.3ms
# Speed: 14.6ms preprocess, 87.3ms inference, 1.3ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 3 gloves, 1 incision, 2 forcepss, 87.1ms
# Speed: 14.6ms preprocess, 87.1ms inference, 1.4ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 3 gloves, 1 incision, 2 forcepss, 86.7ms
# Speed: 14.4ms preprocess, 86.7ms inference, 1.2ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 3 gloves, 1 incision, 2 forcepss, 87.2ms
# Speed: 14.7ms preprocess, 87.2ms inference, 1.4ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 3 gloves, 1 incision, 3 forcepss, 86.8ms
# Speed: 14.3ms preprocess, 86.8ms inference, 1.4ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 3 gloves, 1 incision, 3 forcepss, 1 needle, 87.3ms
# Speed: 14.9ms preprocess, 87.3ms inference, 1.6ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 3 gloves, 1 incision, 3 forcepss, 87.3ms
# Speed: 14.6ms preprocess, 87.3ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 3 gloves, 1 incision, 3 forcepss, 86.8ms
# Speed: 14.6ms preprocess, 86.8ms inference, 1.6ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 3 gloves, 1 incision, 3 forcepss, 1 needle, 87.2ms
# Speed: 14.5ms preprocess, 87.2ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 1 needle, 86.9ms
# Speed: 14.7ms preprocess, 86.9ms inference, 1.4ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 1 needle, 86.9ms
# Speed: 14.6ms preprocess, 86.9ms inference, 1.4ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 1 needle, 87.3ms
# Speed: 14.4ms preprocess, 87.3ms inference, 1.4ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 1 needle, 87.2ms
# Speed: 14.5ms preprocess, 87.2ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 1 needle, 86.7ms
# Speed: 14.7ms preprocess, 86.7ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 1 needle, 87.2ms
# Speed: 14.4ms preprocess, 87.2ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 1 needle, 86.8ms
# Speed: 14.3ms preprocess, 86.8ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 1 needle, 87.3ms
# Speed: 14.5ms preprocess, 87.3ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 5 gloves, 1 incision, 3 forcepss, 1 needle, 87.2ms
# Speed: 14.9ms preprocess, 87.2ms inference, 1.7ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 5 gloves, 1 incision, 3 forcepss, 1 needle, 87.2ms
# Speed: 14.8ms preprocess, 87.2ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 5 gloves, 1 incision, 3 forcepss, 1 needle, 86.9ms
# Speed: 14.3ms preprocess, 86.9ms inference, 1.4ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 5 gloves, 1 incision, 3 forcepss, 1 needle, 87.2ms
# Speed: 14.4ms preprocess, 87.2ms inference, 1.4ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 5 gloves, 1 incision, 3 forcepss, 1 needle, 87.2ms
# Speed: 14.7ms preprocess, 87.2ms inference, 1.4ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 5 gloves, 1 incision, 3 forcepss, 1 needle, 87.2ms
# Speed: 14.5ms preprocess, 87.2ms inference, 1.6ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 5 gloves, 1 incision, 3 forcepss, 87.2ms
# Speed: 14.7ms preprocess, 87.2ms inference, 1.3ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 5 gloves, 1 incision, 3 forcepss, 1 needle, 87.0ms
# Speed: 14.5ms preprocess, 87.0ms inference, 1.6ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 2 gauzes, 4 gloves, 1 incision, 3 forcepss, 87.1ms
# Speed: 14.8ms preprocess, 87.1ms inference, 1.4ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 2 gauzes, 5 gloves, 1 incision, 3 forcepss, 1 needle, 87.1ms
# Speed: 15.0ms preprocess, 87.1ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 5 gloves, 1 incision, 3 forcepss, 1 needle, 87.2ms
# Speed: 14.7ms preprocess, 87.2ms inference, 1.4ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 5 gloves, 1 incision, 3 forcepss, 1 needle, 86.6ms
# Speed: 14.5ms preprocess, 86.6ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 86.9ms
# Speed: 14.6ms preprocess, 86.9ms inference, 1.4ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 87.3ms
# Speed: 14.6ms preprocess, 87.3ms inference, 1.2ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 87.1ms
# Speed: 14.7ms preprocess, 87.1ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 86.8ms
# Speed: 14.7ms preprocess, 86.8ms inference, 1.4ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 86.8ms
# Speed: 14.9ms preprocess, 86.8ms inference, 1.4ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 87.2ms
# Speed: 14.6ms preprocess, 87.2ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 87.3ms
# Speed: 14.7ms preprocess, 87.3ms inference, 1.3ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 87.3ms
# Speed: 14.7ms preprocess, 87.3ms inference, 1.4ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 86.9ms
# Speed: 14.8ms preprocess, 86.9ms inference, 1.3ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 87.2ms
# Speed: 14.6ms preprocess, 87.2ms inference, 1.6ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 87.3ms
# Speed: 14.9ms preprocess, 87.3ms inference, 1.4ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 87.2ms
# Speed: 14.2ms preprocess, 87.2ms inference, 1.4ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 87.3ms
# Speed: 14.9ms preprocess, 87.3ms inference, 1.4ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 86.8ms
# Speed: 14.6ms preprocess, 86.8ms inference, 1.3ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 86.9ms
# Speed: 14.7ms preprocess, 86.9ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 87.3ms
# Speed: 14.6ms preprocess, 87.3ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 86.9ms
# Speed: 14.6ms preprocess, 86.9ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 87.3ms
# Speed: 14.5ms preprocess, 87.3ms inference, 1.4ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 86.7ms
# Speed: 14.6ms preprocess, 86.7ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 87.2ms
# Speed: 14.8ms preprocess, 87.2ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 87.3ms
# Speed: 14.9ms preprocess, 87.3ms inference, 1.4ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 87.4ms
# Speed: 14.5ms preprocess, 87.4ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 87.2ms
# Speed: 14.8ms preprocess, 87.2ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 87.2ms
# Speed: 14.7ms preprocess, 87.2ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 87.3ms
# Speed: 14.7ms preprocess, 87.3ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 86.8ms
# Speed: 14.7ms preprocess, 86.8ms inference, 1.4ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 87.3ms
# Speed: 14.7ms preprocess, 87.3ms inference, 1.6ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 86.9ms
# Speed: 14.5ms preprocess, 86.9ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 87.3ms
# Speed: 15.0ms preprocess, 87.3ms inference, 1.4ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 87.3ms
# Speed: 14.5ms preprocess, 87.3ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 2 forcepss, 86.8ms
# Speed: 15.0ms preprocess, 86.8ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 86.9ms
# Speed: 14.8ms preprocess, 86.9ms inference, 1.4ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 2 forcepss, 87.3ms
# Speed: 14.5ms preprocess, 87.3ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 87.3ms
# Speed: 15.4ms preprocess, 87.3ms inference, 1.6ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 3 sponges, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 87.3ms
# Speed: 17.4ms preprocess, 87.3ms inference, 1.6ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 3 sponges, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 87.3ms
# Speed: 14.5ms preprocess, 87.3ms inference, 1.4ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 3 sponges, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 87.4ms
# Speed: 14.6ms preprocess, 87.4ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 87.3ms
# Speed: 14.5ms preprocess, 87.3ms inference, 1.4ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 86.9ms
# Speed: 14.9ms preprocess, 86.9ms inference, 1.4ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 87.2ms
# Speed: 14.6ms preprocess, 87.2ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 87.0ms
# Speed: 14.8ms preprocess, 87.0ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 87.4ms
# Speed: 19.3ms preprocess, 87.4ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 87.3ms
# Speed: 14.6ms preprocess, 87.3ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 86.9ms
# Speed: 14.6ms preprocess, 86.9ms inference, 1.4ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 86.9ms
# Speed: 14.7ms preprocess, 86.9ms inference, 1.4ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 87.0ms
# Speed: 14.6ms preprocess, 87.0ms inference, 1.4ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 87.0ms
# Speed: 14.8ms preprocess, 87.0ms inference, 1.4ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 87.0ms
# Speed: 14.6ms preprocess, 87.0ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 87.0ms
# Speed: 14.7ms preprocess, 87.0ms inference, 1.2ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 86.9ms
# Speed: 14.2ms preprocess, 86.9ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 87.4ms
# Speed: 14.6ms preprocess, 87.4ms inference, 1.6ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 86.8ms
# Speed: 14.1ms preprocess, 86.8ms inference, 1.4ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 87.3ms
# Speed: 14.3ms preprocess, 87.3ms inference, 1.6ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 87.2ms
# Speed: 14.6ms preprocess, 87.2ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 86.8ms
# Speed: 14.8ms preprocess, 86.8ms inference, 1.6ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 87.3ms
# Speed: 14.4ms preprocess, 87.3ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 87.3ms
# Speed: 14.6ms preprocess, 87.3ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 87.0ms
# Speed: 14.7ms preprocess, 87.0ms inference, 1.4ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 87.3ms
# Speed: 14.5ms preprocess, 87.3ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 86.9ms
# Speed: 14.6ms preprocess, 86.9ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 87.3ms
# Speed: 14.4ms preprocess, 87.3ms inference, 1.4ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 86.9ms
# Speed: 14.6ms preprocess, 86.9ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 86.6ms
# Speed: 14.7ms preprocess, 86.6ms inference, 1.6ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 87.3ms
# Speed: 14.8ms preprocess, 87.3ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 2 gauzes, 4 gloves, 1 incision, 3 forcepss, 87.3ms
# Speed: 14.8ms preprocess, 87.3ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 2 gauzes, 4 gloves, 1 incision, 3 forcepss, 87.3ms
# Speed: 14.4ms preprocess, 87.3ms inference, 1.4ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 87.3ms
# Speed: 14.6ms preprocess, 87.3ms inference, 1.3ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 86.9ms
# Speed: 14.6ms preprocess, 86.9ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 87.4ms
# Speed: 14.8ms preprocess, 87.4ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 87.0ms
# Speed: 15.9ms preprocess, 87.0ms inference, 1.4ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 87.3ms
# Speed: 15.0ms preprocess, 87.3ms inference, 1.6ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 87.0ms
# Speed: 14.5ms preprocess, 87.0ms inference, 1.4ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 87.4ms
# Speed: 14.7ms preprocess, 87.4ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 3 sponges, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 87.4ms
# Speed: 14.6ms preprocess, 87.4ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 87.0ms
# Speed: 15.0ms preprocess, 87.0ms inference, 1.6ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 87.4ms
# Speed: 15.6ms preprocess, 87.4ms inference, 1.4ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 86.9ms
# Speed: 14.7ms preprocess, 86.9ms inference, 1.4ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 87.1ms
# Speed: 14.6ms preprocess, 87.1ms inference, 1.6ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 86.9ms
# Speed: 14.6ms preprocess, 86.9ms inference, 1.3ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 87.5ms
# Speed: 14.6ms preprocess, 87.5ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 87.3ms
# Speed: 14.8ms preprocess, 87.3ms inference, 1.4ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 87.3ms
# Speed: 14.5ms preprocess, 87.3ms inference, 1.4ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 86.6ms
# Speed: 14.7ms preprocess, 86.6ms inference, 1.4ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 87.3ms
# Speed: 14.7ms preprocess, 87.3ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 3 sponges, 2 gauzes, 4 gloves, 1 incision, 3 forcepss, 87.3ms
# Speed: 14.4ms preprocess, 87.3ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 87.4ms
# Speed: 14.5ms preprocess, 87.4ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 86.8ms
# Speed: 14.1ms preprocess, 86.8ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 87.3ms
# Speed: 14.5ms preprocess, 87.3ms inference, 1.6ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 3 sponges, 2 gauzes, 4 gloves, 1 incision, 3 forcepss, 86.8ms
# Speed: 14.5ms preprocess, 86.8ms inference, 1.4ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 87.0ms
# Speed: 14.4ms preprocess, 87.0ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 3 sponges, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 87.2ms
# Speed: 14.9ms preprocess, 87.2ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 87.3ms
# Speed: 14.4ms preprocess, 87.3ms inference, 1.4ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 87.3ms
# Speed: 14.6ms preprocess, 87.3ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 86.9ms
# Speed: 14.4ms preprocess, 86.9ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 86.9ms
# Speed: 14.6ms preprocess, 86.9ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 87.3ms
# Speed: 14.4ms preprocess, 87.3ms inference, 1.3ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 86.9ms
# Speed: 14.7ms preprocess, 86.9ms inference, 1.6ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 86.8ms
# Speed: 14.6ms preprocess, 86.8ms inference, 1.6ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 87.2ms
# Speed: 14.4ms preprocess, 87.2ms inference, 1.3ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 86.7ms
# Speed: 20.2ms preprocess, 86.7ms inference, 1.6ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 87.4ms
# Speed: 14.6ms preprocess, 87.4ms inference, 1.6ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 87.2ms
# Speed: 14.5ms preprocess, 87.2ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 87.0ms
# Speed: 14.6ms preprocess, 87.0ms inference, 1.3ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 86.8ms
# Speed: 14.7ms preprocess, 86.8ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 87.2ms
# Speed: 14.3ms preprocess, 87.2ms inference, 1.3ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 87.4ms
# Speed: 14.3ms preprocess, 87.4ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 87.2ms
# Speed: 14.7ms preprocess, 87.2ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 87.2ms
# Speed: 14.4ms preprocess, 87.2ms inference, 1.4ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 87.1ms
# Speed: 14.3ms preprocess, 87.1ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 1 needle, 87.1ms
# Speed: 18.2ms preprocess, 87.1ms inference, 1.6ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 2 forcepss, 1 needle, 87.0ms
# Speed: 16.1ms preprocess, 87.0ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 1 needle, 87.3ms
# Speed: 14.5ms preprocess, 87.3ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 1 needle, 87.2ms
# Speed: 14.4ms preprocess, 87.2ms inference, 1.2ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 1 needle, 87.4ms
# Speed: 14.2ms preprocess, 87.4ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 1 needle, 86.9ms
# Speed: 14.5ms preprocess, 86.9ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 1 needle, 87.3ms
# Speed: 14.6ms preprocess, 87.3ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 1 needle, 87.3ms
# Speed: 14.4ms preprocess, 87.3ms inference, 1.3ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 1 needle, 87.2ms
# Speed: 14.4ms preprocess, 87.2ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 1 needle, 87.3ms
# Speed: 14.4ms preprocess, 87.3ms inference, 1.4ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 1 needle, 87.3ms
# Speed: 14.1ms preprocess, 87.3ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 2 forcepss, 1 needle, 87.3ms
# Speed: 14.5ms preprocess, 87.3ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 2 forcepss, 1 needle, 87.2ms
# Speed: 14.2ms preprocess, 87.2ms inference, 1.3ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 2 forcepss, 1 needle, 86.8ms
# Speed: 14.5ms preprocess, 86.8ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 2 forcepss, 1 needle, 87.4ms
# Speed: 14.3ms preprocess, 87.4ms inference, 1.6ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 1 needle, 86.8ms
# Speed: 14.4ms preprocess, 86.8ms inference, 1.4ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 1 needle, 87.1ms
# Speed: 15.2ms preprocess, 87.1ms inference, 1.6ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 1 needle, 87.3ms
# Speed: 14.4ms preprocess, 87.3ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 2 forcepss, 1 needle, 87.0ms
# Speed: 15.1ms preprocess, 87.0ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 1 needle, 87.1ms
# Speed: 14.4ms preprocess, 87.1ms inference, 1.6ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 1 needle, 87.4ms
# Speed: 14.4ms preprocess, 87.4ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 2 forcepss, 86.8ms
# Speed: 14.6ms preprocess, 86.8ms inference, 1.6ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 2 forcepss, 1 needle, 86.8ms
# Speed: 14.2ms preprocess, 86.8ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 2 forcepss, 1 needle, 86.9ms
# Speed: 14.4ms preprocess, 86.9ms inference, 1.6ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 1 needle, 87.0ms
# Speed: 14.2ms preprocess, 87.0ms inference, 1.9ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 1 needle, 87.3ms
# Speed: 14.4ms preprocess, 87.3ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 1 needle, 87.3ms
# Speed: 13.9ms preprocess, 87.3ms inference, 1.3ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 3 sponges, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 1 needle, 86.9ms
# Speed: 14.2ms preprocess, 86.9ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 3 sponges, 1 gauze, 3 gloves, 1 incision, 4 forcepss, 1 needle, 87.3ms
# Speed: 14.3ms preprocess, 87.3ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 3 sponges, 1 gauze, 3 gloves, 1 incision, 3 forcepss, 1 needle, 86.9ms
# Speed: 14.1ms preprocess, 86.9ms inference, 1.3ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 3 sponges, 1 gauze, 4 gloves, 1 incision, 2 forcepss, 1 needle, 87.0ms
# Speed: 14.3ms preprocess, 87.0ms inference, 1.4ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 3 sponges, 1 gauze, 4 gloves, 1 incision, 2 forcepss, 1 needle, 86.8ms
# Speed: 14.4ms preprocess, 86.8ms inference, 1.6ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 3 sponges, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 1 needle, 86.9ms
# Speed: 14.2ms preprocess, 86.9ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 3 sponges, 1 gauze, 3 gloves, 1 incision, 2 forcepss, 1 needle, 86.8ms
# Speed: 14.2ms preprocess, 86.8ms inference, 1.3ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 2 sponges, 1 gauze, 3 gloves, 1 incision, 2 forcepss, 1 needle, 87.3ms
# Speed: 14.2ms preprocess, 87.3ms inference, 1.3ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 2 sponges, 1 gauze, 3 gloves, 1 incision, 2 forcepss, 1 needle, 87.3ms
# Speed: 14.2ms preprocess, 87.3ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 3 sponges, 1 gauze, 3 gloves, 1 incision, 2 forcepss, 1 needle, 87.0ms
# Speed: 13.9ms preprocess, 87.0ms inference, 1.4ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 2 sponges, 1 gauze, 2 gloves, 1 incision, 2 forcepss, 1 needle, 86.9ms
# Speed: 14.4ms preprocess, 86.9ms inference, 1.4ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 3 gloves, 1 incision, 2 forcepss, 1 needle, 87.3ms
# Speed: 14.0ms preprocess, 87.3ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 2 gloves, 1 incision, 3 forcepss, 1 needle, 86.8ms
# Speed: 14.1ms preprocess, 86.8ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 1 needle, 87.3ms
# Speed: 14.3ms preprocess, 87.3ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 4 forcepss, 1 needle, 87.2ms
# Speed: 14.3ms preprocess, 87.2ms inference, 1.3ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 4 forcepss, 1 needle, 87.2ms
# Speed: 14.3ms preprocess, 87.2ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 4 forcepss, 1 needle, 86.9ms
# Speed: 14.2ms preprocess, 86.9ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 1 needle, 87.4ms
# ...
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 1 needle, 86.9ms
# Speed: 14.3ms preprocess, 86.9ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 1 needle, 87.2ms
# Speed: 14.2ms preprocess, 87.2ms inference, 1.2ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 1 needle, 87.2ms
# Speed: 13.9ms preprocess, 87.2ms inference, 1.3ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 1 needle, 87.4ms
# Speed: 13.9ms preprocess, 87.4ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 1 needle, 87.2ms
# Speed: 14.2ms preprocess, 87.2ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 1 needle, 86.9ms
# Speed: 14.3ms preprocess, 86.9ms inference, 1.6ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 1 needle, 87.2ms
# Speed: 14.4ms preprocess, 87.2ms inference, 1.4ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 1 needle, 87.3ms
# Speed: 14.3ms preprocess, 87.3ms inference, 1.9ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 1 needle, 87.9ms
# Speed: 14.2ms preprocess, 87.9ms inference, 2.0ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 1 needle, 87.2ms
# Speed: 14.4ms preprocess, 87.2ms inference, 1.3ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 1 needle, 87.3ms
# Speed: 14.3ms preprocess, 87.3ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 1 needle, 87.3ms
# Speed: 14.4ms preprocess, 87.3ms inference, 1.4ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 1 needle, 87.1ms
# Speed: 14.1ms preprocess, 87.1ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 1 needle, 87.3ms
# Speed: 14.3ms preprocess, 87.3ms inference, 1.4ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 1 needle, 87.4ms
# Speed: 14.2ms preprocess, 87.4ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 1 needle, 87.4ms
# Speed: 14.2ms preprocess, 87.4ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 1 needle, 87.3ms
# Speed: 14.1ms preprocess, 87.3ms inference, 1.3ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 1 needle, 87.3ms
# Speed: 14.3ms preprocess, 87.3ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 1 needle, 87.3ms
# Speed: 14.2ms preprocess, 87.3ms inference, 1.6ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 1 needle, 87.0ms
# Speed: 14.2ms preprocess, 87.0ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 1 needle, 87.2ms
# Speed: 14.2ms preprocess, 87.2ms inference, 1.4ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 1 needle, 87.2ms
# Speed: 14.3ms preprocess, 87.2ms inference, 1.3ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 1 needle, 87.3ms
# Speed: 14.3ms preprocess, 87.3ms inference, 1.6ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 1 needle, 86.9ms
# Speed: 14.4ms preprocess, 86.9ms inference, 1.4ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 1 needle, 87.3ms
# Speed: 14.2ms preprocess, 87.3ms inference, 1.4ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 1 needle, 86.9ms
# Speed: 14.3ms preprocess, 86.9ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 1 needle, 86.9ms
# Speed: 13.9ms preprocess, 86.9ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 1 needle, 87.4ms
# Speed: 14.2ms preprocess, 87.4ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 1 needle, 86.9ms
# Speed: 14.4ms preprocess, 86.9ms inference, 1.4ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 1 needle, 87.3ms
# Speed: 14.3ms preprocess, 87.3ms inference, 1.2ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 1 needle, 87.3ms
# Speed: 14.4ms preprocess, 87.3ms inference, 1.4ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 87.3ms
# Speed: 14.2ms preprocess, 87.3ms inference, 1.3ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 87.4ms
# Speed: 14.0ms preprocess, 87.4ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 87.3ms
# Speed: 14.2ms preprocess, 87.3ms inference, 1.3ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 87.0ms
# Speed: 14.1ms preprocess, 87.0ms inference, 1.6ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 87.3ms
# Speed: 14.3ms preprocess, 87.3ms inference, 1.6ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 87.3ms
# Speed: 13.7ms preprocess, 87.3ms inference, 1.4ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 87.3ms
# Speed: 14.2ms preprocess, 87.3ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 86.9ms
# Speed: 14.2ms preprocess, 86.9ms inference, 1.4ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 87.4ms
# Speed: 14.2ms preprocess, 87.4ms inference, 1.4ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 86.7ms
# Speed: 14.3ms preprocess, 86.7ms inference, 1.4ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 87.3ms
# Speed: 14.3ms preprocess, 87.3ms inference, 1.4ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 87.3ms
# Speed: 14.3ms preprocess, 87.3ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 87.3ms
# Speed: 14.2ms preprocess, 87.3ms inference, 1.6ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 87.0ms
# Speed: 14.2ms preprocess, 87.0ms inference, 1.6ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 87.3ms
# Speed: 13.9ms preprocess, 87.3ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 87.0ms
# Speed: 14.3ms preprocess, 87.0ms inference, 1.7ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 87.4ms
# Speed: 15.6ms preprocess, 87.4ms inference, 1.7ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 1 needle, 87.1ms
# Speed: 18.4ms preprocess, 87.1ms inference, 1.6ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 1 needle, 86.6ms
# Speed: 14.2ms preprocess, 86.6ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 1 needle, 86.8ms
# Speed: 14.4ms preprocess, 86.8ms inference, 1.4ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 1 needle, 87.0ms
# Speed: 14.3ms preprocess, 87.0ms inference, 1.6ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 1 needle, 87.0ms
# Speed: 14.2ms preprocess, 87.0ms inference, 1.6ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 sponge, 1 gauze, 3 gloves, 1 incision, 3 forcepss, 1 needle, 87.4ms
# Speed: 13.7ms preprocess, 87.4ms inference, 1.2ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 1 needle, 87.3ms
# Speed: 14.1ms preprocess, 87.3ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 1 needle, 87.2ms
# Speed: 14.3ms preprocess, 87.2ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 1 needle, 87.1ms
# Speed: 14.3ms preprocess, 87.1ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 2 forcepss, 1 needle, 87.3ms
# Speed: 15.5ms preprocess, 87.3ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 1 needle, 87.0ms
# Speed: 14.2ms preprocess, 87.0ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 1 needle, 87.3ms
# Speed: 14.1ms preprocess, 87.3ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 1 needle, 87.0ms
# Speed: 14.3ms preprocess, 87.0ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 1 needle, 86.9ms
# Speed: 14.3ms preprocess, 86.9ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 1 needle, 87.3ms
# Speed: 14.3ms preprocess, 87.3ms inference, 1.4ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 1 needle, 87.3ms
# Speed: 14.4ms preprocess, 87.3ms inference, 1.4ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 1 needle, 87.0ms
# Speed: 14.2ms preprocess, 87.0ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 87.3ms
# Speed: 14.1ms preprocess, 87.3ms inference, 1.4ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 86.7ms
# Speed: 14.2ms preprocess, 86.7ms inference, 1.3ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 87.3ms
# Speed: 13.9ms preprocess, 87.3ms inference, 1.3ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 86.9ms
# Speed: 14.2ms preprocess, 86.9ms inference, 1.4ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 87.0ms
# Speed: 13.7ms preprocess, 87.0ms inference, 1.4ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 87.5ms
# Speed: 14.2ms preprocess, 87.5ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 2 forcepss, 1 needle, 87.3ms
# Speed: 14.4ms preprocess, 87.3ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 4 gloves, 1 incision, 3 forcepss, 1 needle, 86.9ms
# Speed: 14.3ms preprocess, 86.9ms inference, 1.3ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 3 gloves, 1 incision, 2 forcepss, 87.3ms
# Speed: 14.4ms preprocess, 87.3ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 3 gloves, 1 incision, 1 forceps, 1 needle, 87.4ms
# Speed: 14.3ms preprocess, 87.4ms inference, 1.3ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 3 gloves, 1 incision, 1 forceps, 1 needle, 87.4ms
# Speed: 16.2ms preprocess, 87.4ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 2 sponges, 1 gauze, 3 gloves, 1 incision, 1 forceps, 1 needle, 87.4ms
# Speed: 14.4ms preprocess, 87.4ms inference, 1.2ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 gauze, 3 gloves, 1 incision, 2 forcepss, 1 needle, 87.1ms
# Speed: 14.3ms preprocess, 87.1ms inference, 1.6ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 sponge, 1 gauze, 3 gloves, 1 incision, 2 forcepss, 1 needle, 87.3ms
# Speed: 14.3ms preprocess, 87.3ms inference, 1.3ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 gauze, 3 gloves, 1 incision, 2 forcepss, 1 needle, 87.3ms
# Speed: 14.0ms preprocess, 87.3ms inference, 1.2ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 sponge, 1 gauze, 3 gloves, 1 incision, 1 forceps, 1 needle, 87.2ms
# Speed: 13.9ms preprocess, 87.2ms inference, 1.6ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 gauze, 3 gloves, 1 incision, 2 forcepss, 1 needle, 87.0ms
# Speed: 14.1ms preprocess, 87.0ms inference, 1.3ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 gauze, 3 gloves, 1 incision, 1 forceps, 1 needle, 87.3ms
# Speed: 14.0ms preprocess, 87.3ms inference, 1.4ms postprocess per image at shape (1, 3, 2048, 2048)
#
# 0: 2048x2048 1 clamp, 1 gauze, 3 gloves, 1 incision, 1 forceps, 1 needle, 87.1ms
# Speed: 14.2ms preprocess, 87.1ms inference, 1.5ms postprocess per image at shape (1, 3, 2048, 2048)
# Video frame is empty or video processing has been successfully completed.

# %% [markdown]
# # Additional Resources
#
# ## Community Support
#
# For more information on counting objects with Ultralytics, you can explore the comprehensive [Ultralytics Object Counting Docs](https://docs.ultralytics.com/guides/object-counting/). This guide covers everything from basic concepts to advanced techniques, ensuring you get the most out of counting and visualization.
#
# ## Ultralytics ⚡ Resources
#
# At Ultralytics, we are committed to providing cutting-edge AI solutions. Here are some key resources to learn more about our company and get involved with our community:
#
# - [Ultralytics HUB](https://ultralytics.com/hub): Simplify your AI projects with Ultralytics HUB, our no-code tool for effortless YOLO training and deployment.
# - [Ultralytics Licensing](https://ultralytics.com/license): Review our licensing terms to understand how you can use our software in your projects.
# - [About Us](https://ultralytics.com/about): Discover our mission, vision, and the story behind Ultralytics.
# - [Join Our Team](https://ultralytics.com/work): Explore career opportunities and join our team of talented professionals.
#
# ## YOLO11 🚀 Resources
#
# YOLO11 is the latest evolution in the YOLO series, offering state-of-the-art performance in object detection and image segmentation. Here are some essential resources to help you get started with YOLO11:
#
# - [GitHub](https://github.com/ultralytics/ultralytics): Access the YOLO11 repository on GitHub, where you can find the source code, contribute to the project, and report issues.
# - [Docs](https://docs.ultralytics.com/): Explore the official documentation for YOLO11, including installation guides, tutorials, and detailed API references.
# - [Discord](https://ultralytics.com/discord): Join our Discord community to connect with other users, share your projects, and get help from the Ultralytics team.
#
# These resources are designed to help you leverage the full potential of Ultralytics' offerings and YOLO11. Whether you're a beginner or an experienced developer, you'll find the information and support you need to succeed.
